# %%
import pandas as pd

yield_rates1 = pd.read_csv('data/bond-yield/yield-curve-rates-1990-2021.csv')
yield_rates1
# Out:
#           Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  \
# 0     12/31/21  0.06  0.05  0.06   NaN  0.19  0.39  0.73  0.97  1.26  1.44
# 1     12/30/21  0.06  0.06  0.05   NaN  0.19  0.38  0.73  0.98  1.27  1.44
# 2     12/29/21  0.01  0.02  0.05   NaN  0.19  0.38  0.75  0.99  1.29  1.47
# 3     12/28/21  0.03  0.04  0.06   NaN  0.20  0.39  0.74  0.99  1.27  1.41
# 4     12/27/21  0.04  0.05  0.06   NaN  0.21  0.33  0.76  0.98  1.26  1.41
# ...        ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 8003    1/8/90   NaN   NaN  7.79   NaN  7.88  7.81  7.90  7.95  7.92  8.05
# 8004    1/5/90   NaN   NaN  7.79   NaN  7.85  7.79  7.90  7.94  7.92  8.03
# 8005    1/4/90   NaN   NaN  7.84   NaN  7.90  7.82  7.92  7.93  7.91  8.02
# 8006    1/3/90   NaN   NaN  7.89   NaN  7.94  7.85  7.94  7.96  7.92  8.04
# 8007    1/2/90   NaN   NaN  7.83   NaN  7.89  7.81  7.87  7.90  7.87  7.98
#
#       10 Yr  20 Yr  30 Yr
# 0      1.52   1.94   1.90
# ...

# %%
spread_10_3 = []

for i in range(len(yield_rates1)):
    spread_10_3.append(yield_rates1.loc[i]['10 Yr'] - yield_rates1.loc[i]['3 Mo'])

# spread_10_3
# Out:
# [1.46,
#  1.47,
#  1.5,
#  1.43,
#  1.42,
#  1.43,
#  1.38,
#  1.41,
#  1.3599999999999999,
#  1.3599999999999999,
#  1.39,
#  1.42,
#  1.39,
#  1.3699999999999999,
#  1.42,
#  1.43,
#  1.45,
#  1.42,
#  1.38,
#  1.29,
#  1.39,
#  1.3699999999999999,
#  1.38,
#  1.46,
#  1.42,
#  1.5799999999999998,
#  1.6099999999999999,
#  1.5799999999999998,
#  1.49,
#  1.54,
#  1.55,
#  1.5799999999999998,
#  1.5799999999999998,
#  1.53,
#  1.51,
#  1.42,
#  1.45,
#  1.4,
#  1.49,
#  1.55,
#  1.51,
#  1.53,
#  1.5,
#  1.51,
#  1.48,
#  1.5699999999999998,
#  1.5799999999999998,
#  1.5999999999999999,
#  1.6199999999999999,
#  1.5999999999999999,
#  1.5999999999999999,
#  1.53,
#  1.54,
#  1.47,
#  1.51,
#  1.53,
#  1.56,
#  1.53,
#  1.49,
#  1.5,
#  1.45,
#  1.44,
#  1.48,
#  1.51,
#  1.5,
#  1.44,
#  1.44,
#  1.38,
#  1.29,
#  1.3,
#  1.27,
#  1.33,
#  1.3,
#  1.27,
#  1.24,
#  1.27,
#  1.3,
#  1.26,
#  1.3,
#  1.3299999999999998,
#  1.28,
#  1.24,
#  1.26,
#  1.26,
#  1.24,
#  1.26,
#  1.29,
# ...

# %%
dates = pd.to_datetime(yield_rates1['Date'])

df_reversed = pd.DataFrame({
    'Date': dates,
    '10 Yr': yield_rates1['10 Yr'],
    '3 Mo': yield_rates1['3 Mo'],
    'Spread': spread_10_3
})

df = df_reversed.copy().dropna().iloc[::-1]
df = df.set_index(df['Date'])
df = df.drop(columns='Date')
df_2005_09 = df['2005':'2009']
df_2005_09.to_csv('2005_2009_10_yr.csv')
