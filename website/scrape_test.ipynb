# %%
import pandas as pd

tables = pd.read_html('https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2024')

# %%
len(tables)
# Out:
# 1

# %%
tables[0]
# Out:
#            Date  20 YR  30 YR  Extrapolation Factor  8 WEEKS BANK DISCOUNT  \
# 0    01/02/2024    NaN    NaN                   NaN                    NaN
# 1    01/03/2024    NaN    NaN                   NaN                    NaN
# 2    01/04/2024    NaN    NaN                   NaN                    NaN
# 3    01/05/2024    NaN    NaN                   NaN                    NaN
# 4    01/08/2024    NaN    NaN                   NaN                    NaN
# ..          ...    ...    ...                   ...                    ...
# 202  10/22/2024    NaN    NaN                   NaN                    NaN
# 203  10/23/2024    NaN    NaN                   NaN                    NaN
# 204  10/24/2024    NaN    NaN                   NaN                    NaN
# 205  10/25/2024    NaN    NaN                   NaN                    NaN
# 206  10/28/2024    NaN    NaN                   NaN                    NaN
#
# ...

# %%
python manage create my
