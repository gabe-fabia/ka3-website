# %%
import mysql.connector
import pandas as pd
import plotly
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:DiabloDota420!@localhost/ka3")

df = pd.read_sql_query("""
            SELECT a.Date, a.3_Month, a.10_Year, b.Ticker, b.Close
            FROM yield_rates a
            JOIN stocks b ON a.Date = LEFT(b.Date, 10)
            WHERE b.Ticker = "ZUT.TO"
            """
            , engine)
df["10_3_spread"] = df['10_Year'] - df['3_Month']
df
# Out:
#            Date  3_Month  10_Year  Ticker  Close  10_3_spread
# 0    2010-01-25     0.06     3.66  ZUT.TO   7.52         3.60
# 1    2010-02-01     0.10     3.68  ZUT.TO   7.57         3.58
# 2    2010-02-08     0.12     3.62  ZUT.TO   7.72         3.50
# 3    2010-02-22     0.11     3.80  ZUT.TO   7.79         3.69
# 4    2010-03-01     0.13     3.61  ZUT.TO   7.94         3.48
# ..          ...      ...      ...     ...    ...          ...
# 685  2025-01-06     4.35     4.62  ZUT.TO  21.59         0.27
# 686  2025-01-13     4.37     4.79  ZUT.TO  22.07         0.42
# 687  2025-01-27     4.32     4.53  ZUT.TO  21.01         0.21
# 688  2025-02-03     4.34     4.54  ZUT.TO  21.01         0.20
# 689  2025-02-10     4.35     4.51  ZUT.TO  21.07         0.16
#
# [690 rows x 6 columns]
